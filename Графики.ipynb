# %% [markdown]
# графики анализа данных: boxplot, визуализация данны

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# Матрица корреляции

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %% [markdown]
# Обучение нейронной сети

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)
